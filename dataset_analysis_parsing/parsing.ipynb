# %%
import pandas as pd
import string
import re
import datetime

# %%
def parse(text):
    no_punctuation = text.translate(str.maketrans('', '', string.punctuation))
    no_small_words = re.sub(r'\b\w{1,3}\b', '', no_punctuation.lower())
    no_big_spaces = re.sub(' +', ' ', no_small_words)
    return no_big_spaces

# %%
df = pd.read_csv('/home/pietro/Documenti/BigData/first_project_baronato//Reviews_parsed.csv')

# %%
df
# Out:
#             Id   ProductId          UserId  HelpfulnessNumerator  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                     1
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                     0
# 2            3  B000LQOCH0   ABXLMWJIXXAIN                     1
# 3            4  B000UA0QIQ  A395BORC6FGVXV                     3
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T                     0
# ...        ...         ...             ...                   ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                     0
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                     0
# 568451  568452  B004I613EE  A121AA1GQV751Z                     2
# 568452  568453  B004I613EE   A3IBEVCTXKNOH                     1
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                     0
#
#         HelpfulnessDenominator  Score  Time  \
# 0                            1      5  2011
# 1                            0      1  2012
# 2                            1      4  2008
# 3                            3      2  2011
# 4                            0      5  2012
# ...                        ...    ...   ...
# 568449                       0      5  2011
# 568450                       0      2  2012
# 568451                       2      5  2012
# 568452                       1      5  2012
# 568453                       0      5  2012
#
#                                                      Text
# 0        have bought several vitality canned food prod...
# 1       product arrived labeled jumbo salted peanutsth...
# 2       this confection that been around centuries lig...
# 3        looking secret ingredient robitussin believe ...
# 4       great taffy great price there wide assortment ...
# ...                                                   ...
# 568449  great sesame chickenthis good better than rest...
# 568450   disappointed with flavor chocolate notes espe...
# 568451  these stars small give 1015 those training ses...
# 568452  these best treats training rewarding your bein...
# 568453   very satisfied product advertised cereal with...
#
# [568454 rows x 8 columns]

# %%
count = 0
for i in range(0, len(df)):
    if '   ' in df.at[i, 'Text']:
        count += 1
        # print(df.at[i, 'Text'])
print(count)
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
df = df.drop(['ProfileName', 'Summary'], axis = 1)

# %%
df
# Out:
#             Id   ProductId          UserId  HelpfulnessNumerator  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                     1
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                     0
# 2            3  B000LQOCH0   ABXLMWJIXXAIN                     1
# 3            4  B000UA0QIQ  A395BORC6FGVXV                     3
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T                     0
# ...        ...         ...             ...                   ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                     0
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                     0
# 568451  568452  B004I613EE  A121AA1GQV751Z                     2
# 568452  568453  B004I613EE   A3IBEVCTXKNOH                     1
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                     0
#
#         HelpfulnessDenominator  Score        Time  \
# 0                            1      5  1303862400
# 1                            0      1  1346976000
# 2                            1      4  1219017600
# 3                            3      2  1307923200
# 4                            0      5  1350777600
# ...                        ...    ...         ...
# 568449                       0      5  1299628800
# 568450                       0      2  1331251200
# 568451                       2      5  1329782400
# 568452                       1      5  1331596800
# 568453                       0      5  1338422400
#
#                                                      Text
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price.  There was a wid...
# ...                                                   ...
# 568449  Great for sesame chicken..this is a good if no...
# 568450  I'm disappointed with the flavor. The chocolat...
# 568451  These stars are small, so you can give 10-15 o...
# 568452  These are the BEST treats for training and rew...
# 568453  I am very satisfied ,product is as advertised,...
#
# [568454 rows x 8 columns]

# %%
for i in range(0, len(df)):
    df.at[i, 'Text'] = parse(df.at[i, 'Text'])
    try:
        date_time = datetime.datetime.fromtimestamp(int(df.at[i, 'Time']))
    except ValueError:
        continue
    date = date_time.strftime('%Y-%m-%d %H:%M:%S')
    year = date.split('-')[0]
    try:
        int_year = int(year)
    except ValueError:
        continue
    df.at[i, 'Time'] = int_year

# %%
df
# Out:
#             Id   ProductId          UserId  HelpfulnessNumerator  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                     1
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                     0
# 2            3  B000LQOCH0   ABXLMWJIXXAIN                     1
# 3            4  B000UA0QIQ  A395BORC6FGVXV                     3
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T                     0
# ...        ...         ...             ...                   ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                     0
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                     0
# 568451  568452  B004I613EE  A121AA1GQV751Z                     2
# 568452  568453  B004I613EE   A3IBEVCTXKNOH                     1
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                     0
#
#         HelpfulnessDenominator  Score  Time  \
# 0                            1      5  2011
# 1                            0      1  2012
# 2                            1      4  2008
# 3                            3      2  2011
# 4                            0      5  2012
# ...                        ...    ...   ...
# 568449                       0      5  2011
# 568450                       0      2  2012
# 568451                       2      5  2012
# 568452                       1      5  2012
# 568453                       0      5  2012
#
#                                                      Text
# 0        have bought several   vitality canned  food p...
# 1       product arrived labeled  jumbo salted peanutst...
# 2       this   confection that  been around   centurie...
# 3          looking   secret ingredient  robitussin  be...
# 4       great taffy   great price  there   wide assort...
# ...                                                   ...
# 568449  great  sesame chickenthis   good   better than...
# 568450   disappointed with  flavor  chocolate notes  e...
# 568451  these stars  small    give 1015  those   train...
# 568452  these   best treats  training  rewarding your ...
# 568453    very satisfied product   advertised     cere...
#
# [568454 rows x 8 columns]

# %%
print(df['Time'].unique())
# Out:
# [2011 2012 2008 2005 2010 2009 2006 2007 2004 2000 2003 2002 2001 1999]

# %%
df.to_csv(r'.\..\..\Reviews_parsed.csv', index = None)
